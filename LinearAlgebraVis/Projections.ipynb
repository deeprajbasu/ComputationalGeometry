# %%
from manim import *
import numpy as np
# Out:
# Manim Community v0.8.0

# %%
#Basis Matrix        
x = np.array([[1, 0, 0], [0, 1, 0], [0, 0, 1]])

#Target Position        
target = np.array([3, 4, 5])

# np.multiply(x, y)

#y=x
def Line_s1(x) : 
    return float((1*x)+0)

#y=-x
def Line_s2(x) : 
    return float((-1*x)+0)

#y=x/2
def Line_s3(x) : 
    return float((0.5*x)+0)

# %%
# %%manim -qm -v WARNING ThreeDCameraIllusionRotation
#
# class ThreeDCameraIllusionRotation(ThreeDScene):
#     def construct(self):
#         axes = ThreeDAxes(z_normal=[0,0,1])
#         self.set_camera_orientation(phi=45 * DEGREES, theta=30 * DEGREES,distance=500)
#         self.begin_ambient_camera_rotation(rate=0.2)
#
#         #arrays to multiply
#
#         #Vector x
#         x = np.array([[1, 0, 0], [0, 1, 0], [0, 0, 1]])
#
#         self.add(axes)
#
#
#         #visulaise target as sphere
#         sphere1 = Sphere(
#             center=(3, 4, 5),
#             radius=0.2,
#             resolution=(20, 20),
#         )
#         sphere1.set_color(RED)
#         self.add(sphere1)
#
#         #add line S1
#         self.add(Line([5,Line_s1(5),0],[-5,Line_s1(-5),0],color=GREEN))
#
#
#         v = np.array([100, Line_s1(100), 0])
#
#         #draw perpendicular from target to line project on line
#
#         # finding norm of the vector v
#         v_norm = np.sqrt(sum(v**2))
#
#         # Apply the formula as mentioned above
#         # for projecting a vector onto another vector
#         # find dot product using np.dot()
#         proj_of_u_on_v = (np.dot(target, v)/v_norm**2)*v
#
#         self.add(Line(target,proj_of_u_on_v,color=BLUE))
#         print(proj_of_u_on_v)
# Out:
# [3.5 3.5 0. ]

# %%
#for line s2

# %%
# %%manim -qm -v WARNING ThreeDCameraIllusionRotation
#
# class ThreeDCameraIllusionRotation(ThreeDScene):
#     def construct(self):
#         axes = ThreeDAxes(z_normal=[0,0,1])
#         self.set_camera_orientation(phi=60 * DEGREES, theta=30 * DEGREES,distance=500)
#         self.begin_ambient_camera_rotation(rate=0.2)
#
#         #arrays to multiply
#
#         #Vector x
#         x = np.array([[1, 0, 0], [0, 1, 0], [0, 0, 1]])
#
#         self.add(axes)
#
#
#         #visulaise target as sphere
#         sphere1 = Sphere(
#             center=(3, 4, 5),
#             radius=0.2,
#             resolution=(20, 20),
#         )
#         sphere1.set_color(RED)
#         self.add(sphere1)
#
#         #add line S1
#         self.add(Line([5,Line_s2(5),0],[-5,Line_s2(-5),0],color=GREEN))
#
#
#         v = np.array([100, Line_s2(100), 0])
#
#         #draw perpendicular from target to line project on line
#
#         # finding norm of the vector v
#         v_norm = np.sqrt(sum(v**2))
#
#         # Apply the formula as mentioned above
#         # for projecting a vector onto another vector
#         # find dot product using np.dot()
#         proj_of_u_on_v = (np.dot(target, v)/v_norm**2)*v
#
#         self.add(Line(target,proj_of_u_on_v,color=BLUE))
#         print(proj_of_u_on_v)
#
#         self.wait(0.6)
# #         self.begin_ambient_camera_rotation()
# Out:
# [-0.5  0.5 -0. ]
# <video src="media/jupyter/ThreeDCameraIllusionRotation@2021-07-18@22-27-22.mp4" controls autoplay loop style="max-width: 25vw;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
#for line s3

# %%
# %%manim -qm -v WARNING ThreeDCameraIllusionRotation
#
# class ThreeDCameraIllusionRotation(ThreeDScene):
#     def construct(self):
#         axes = ThreeDAxes(z_normal=[0,0,1])
#         self.set_camera_orientation(phi=60 * DEGREES, theta=30 * DEGREES,distance=500)
#         self.begin_ambient_camera_rotation(rate=0.2)
#
#         #arrays to multiply
#
#         #Vector x
#         x = np.array([[1, 0, 0], [0, 1, 0], [0, 0, 1]])
#
#         self.add(axes)
#
#         #visulaise target as sphere
#         sphere1 = Sphere(
#             center=(3, 4, 5),
#             radius=0.2,
#             resolution=(20, 20),
#         )
#         sphere1.set_color(RED)
#         self.add(sphere1)
#
#         #add line S1
#         self.add(Line([5,Line_s3(5),0],[-5,Line_s3(-5),0],color=GREEN))
#
#
#         v = np.array([100, Line_s3(100), 0])
#
#         #draw perpendicular from target to line project on line
#
#         # finding norm of the vector v
#         v_norm = np.sqrt(sum(v**2))
#
#         # Apply the formula as mentioned above
#         # for projecting a vector onto another vector
#         # find dot product using np.dot()
#         proj_of_u_on_v = (np.dot(target, v)/v_norm**2)*v
#
#         self.add(Line(target,proj_of_u_on_v,color=BLUE))
#         print(proj_of_u_on_v)
#
#         self.wait(2)
# #         self.begin_ambient_camera_rotation()
# Out:
# [4. 2. 0.]
# <video src="media/jupyter/ThreeDCameraIllusionRotation@2021-07-18@22-31-00.mp4" controls autoplay loop style="max-width: 25vw;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
#project on plane

import numpy as np

p1 = np.array([1, -1, 0])
p2 = np.array([0, -1, 1])
p3 = np.array([-1,0 , 1])

# These two vectors are in the plane
v1 = p3 - p1
v2 = p2 - p1

# the cross product is a vector normal to the plane
cp = np.cross(v1, v2)
a, b, c = cp

# This evaluates a * x3 + b * y3 + c * z3 which equals d
d = np.dot(cp, p3)

print('The equation is {0}x + {1}y + {2}z = {3}'.format(a, b, c, d))


def func(x, y):
    return np.array([x, y, -1*(x+y)])
# Out:
# The equation is 1x + 1y + 1z = 0

# %%
v = func(3,4)
v
# Out:
# array([ 3,  4, -7])

# %%
# %%manim -qm -v WARNING ThreeDCameraIllusionRotation
#
# class ThreeDCameraIllusionRotation(ThreeDScene):
#     def construct(self):
#         axes = ThreeDAxes(z_normal=[0,0,1])
#         self.set_camera_orientation(phi=66 * DEGREES, theta=5 * DEGREES,distance=500000)
#         self.begin_ambient_camera_rotation(rate=0.2)
#         self.add(axes)
#
#         #visulaise target as sphere
#         sphere1 = Sphere(
#             center=(3, 4, 5),
#             radius=0.2,
#             resolution=(20, 20),
#         )
#         sphere1.set_color(RED)
#         self.add(sphere1)
#
#
#         surface = ParametricSurface(
#             lambda u, v: axes.c2p(*func(u, v)),
#             u_min=-5,
#             u_max=5,
#             v_min=-5,
#             v_max=5,
#         )
#         self.add(surface)
#         v = func(30,40)
#         #draw random vector on surface
#         self.add(Line([0,0,0],v,color=RED))
#
#         #draw perpendicular from target to line project on line
#
#         # finding norm of the vector v
#         v_norm = np.sqrt(sum(v**2))
#
#         # Apply the formula as mentioned above
#         # for projecting a vector onto another vector
#         # find dot product using np.dot()
#         proj_of_u_on_v = (np.dot(target, v)/v_norm**2)*v
#
#         self.add(Line(target,proj_of_u_on_v,color=BLUE))
#         print(proj_of_u_on_v)
#
#         self.add(Line(target,np.array([-1, 0.5, 1.5]),color=YELLOW))
#         #Draw orthagonal Vector to v
#
#         self.wait(1)
# #         self.begin_ambient_camera_rotation()
# Out:
# [-0.40540541 -0.54054054  0.94594595]
# <video src="media/jupyter/ThreeDCameraIllusionRotation@2021-07-18@23-57-10.mp4" controls autoplay loop style="max-width: 25vw;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
angle(np.array([3, 4, 5]),np.array([-1, 0.5, 1.5]))
# Out:
# 1.057152860382729

# %%
import math

def dotproduct(v1, v2):
  return sum((a*b) for a, b in zip(v1, v2))

def length(v):
  return dotproduct(v, v)

def angle(v1, v2):
  return math.acos(dotproduct(v1, v2) / math.sqrt(length(v1) * length(v2)))

# %%
math.acos(0)
# Out:
# 1.5707963267948966

# %%
a  = np.array([3, 4, 5])
b  = np.array([3.5, 3.5, 0])


dist = np.linalg.norm(a-b)
dist
# Out:
# 5.049752469181039

# %%
a  = np.array([3, 4, 5])
b  = np.array([-0.5, 3.5, 0])


dist = np.linalg.norm(a-b)
dist
